# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\user\anaconda3\lib\site-packages (1.42.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\user\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.25.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Google Sheets API Authentication
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name('forms-automation-key.json', scope)
client = gspread.authorize(creds)
sheet = client.open('Capstone Project Registration').sheet1

# Streamlit App
st.title("📋 Capstone Project Registration Form")

# Form Fields
with st.form(key='capstone_form'):
    name = st.text_input("Name")
    reg_no = st.text_input("Registration Number")
    gender = st.radio("Gender", ["Male", "Female"])
    mobile = st.text_input("Mobile")
    email = st.text_input("Email")
    specialization = st.selectbox("Major Specialization", ["Finance", "HR", "Marketing", "Business Analytics"])
    
    industry_options = [
        "Real Estate - House Price Prediction",
        "BFSI - Life Insurance Sales",
        "E-commerce - Customer Churn Prediction",
        "Sports - Cricket Win Prediction",
        "Healthcare - Life Insurance Cost",
        "HR - Salary Prediction",
        "Social Media - Tourism Adoption Project",
        "Supply Chain - Product Shipment Weight",
        "Banking - Probability of Default"
    ]
    industry_choice = st.selectbox("Preferred Industry/Function", industry_options)
    
    justification = st.text_area("Justify your preference")

    # Submit Button
    submit_button = st.form_submit_button(label='Submit')

# Save to Google Sheet on Submission
if submit_button:
    sheet.append_row([name, reg_no, gender, mobile, email, specialization, industry_choice, justification])
    st.success("✅ Response Submitted Successfully!")
# Out:
# 2025-02-07 12:02:41.607 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.029
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\User\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-02-07 12:02:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.043 Session state does not function when running a script without `streamlit run`
# 2025-02-07 12:02:43.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-07 12:02:43.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
